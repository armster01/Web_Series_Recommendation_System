# %% [markdown]
# #Importing The Dependencies

# %%
import numpy as np
import pandas as pd
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# #Data Collection And Pre-Processing

# %%
web_series_data = pd.read_csv('/content/All_Streaming_Shows.csv')

# %%
web_series_data.head()
# Out:
#       Series Title  Year Released Content Rating  IMDB Rating  R Rating  \
# 0     Breaking Bad           2008            18+          9.5       100
# 1  Game of Thrones           2011            18+          9.3        99
# 2   Rick and Morty           2013            18+          9.2        97
# 3  Stranger Things           2016            16+          8.8        96
# 4         The Boys           2019            18+          8.7        95
#
#                        Genre  \
# 0                Crime,Drama
# 1   Action & Adventure,Drama
# 2           Animation,Comedy
# 3              Drama,Fantasy
# 4  Action & Adventure,Comedy
#
#                                          Description No of Seasons  \
# 0  When Walter White, a New Mexico chemistry teac...      5Seasons
# 1  Seven noble families fight for control of the ...      8Seasons
# 2  Rick is a mentally-unbalanced but scientifical...      4Seasons
# 3  When a young boy vanishes, a small town uncove...      3Seasons
# 4  A group of vigilantes known informally as “The...      2Seasons
#
#            Streaming Platform
# 0                     Netflix
# 1                 HBO MAX,HBO
# 2  Free Services,HBO MAX,Hulu
# 3                     Netflix
# 4                 Prime Video

# %%
web_series_data.shape
# Out:
# (12353, 9)

# %%
selected_features = ['Content Rating','IMDB Rating','R Rating','Genre','Description','Streaming Platform']
print(selected_features)
# Out:
# ['Content Rating', 'IMDB Rating', 'R Rating', 'Genre', 'Description', 'Streaming Platform']

# %%
for feature in selected_features:
  web_series_data[feature] = web_series_data[feature].fillna('')

# %%
combined_features = web_series_data['Content Rating'].astype(str)+' '+web_series_data['IMDB Rating'].astype(str)+' '+web_series_data['R Rating'].astype(str)+' '+web_series_data['Genre'].astype(str)+' '+web_series_data['Description'].astype(str)+' '+web_series_data['Streaming Platform'].astype(str)

# %%
print(combined_features)
# Out:
# 0        18+ 9.5 100 Crime,Drama When Walter White, a N...
# 1        18+ 9.3 99 Action & Adventure,Drama Seven nobl...
# 2        18+ 9.2 97 Animation,Comedy Rick is a mentally...
# 3        16+ 8.8 96 Drama,Fantasy When a young boy vani...
# 4        18+ 8.7 95 Action & Adventure,Comedy A group o...
#                                ...
# 12348      -1 2017,Prime Video A Fishing Story with Ron...
# 12349                                          -1 -1 -1 -1
# 12350      -1 2016,Prime Video Road to the NHL Outdoor ...
# 12351      -1 2018,Prime Video Addy Media has one or mo...
# 12352      -1 2014,Free Services My Dream Derelict Home...
# Length: 12353, dtype: object

# %%
vectorizer = TfidfVectorizer()

# %%
feature_vectors = vectorizer.fit_transform(combined_features)

# %%
print(feature_vectors)
# Out:
#   (0, 256)	0.05721753118520185
#   (0, 117)	0.10796586723381307
#   (0, 9788)	0.18019612062681198
#   (0, 12159)	0.09273053071967656
#   (0, 42722)	0.06601734920667847
#   (0, 42307)	0.14094981519161914
#   (0, 42760)	0.10607770577095663
#   (0, 27645)	0.06308451820233883
#   (0, 25763)	0.12888653750403972
#   (0, 7807)	0.15177237806096944
#   (0, 38991)	0.12203334924785361
#   (0, 20363)	0.041277156880299135
#   (0, 11287)	0.15975019979941793
#   (0, 43030)	0.08186159572897687
#   (0, 37267)	0.11958770101248102
#   (0, 19365)	0.14423672615256647
#   (0, 6942)	0.1618232447923916
#   (0, 2813)	0.172140873612601
#   (0, 16437)	0.11504446576848291
#   (0, 31185)	0.19141706461155536
#   (0, 28398)	0.09012578091568132
#   (0, 28576)	0.0774953751925665
#   (0, 40749)	0.06685766055983533
#   (0, 43522)	0.07848245259862584
#   (0, 23112)	0.10354706505190957
#   :	:
#   (12352, 28556)	0.10831112178959441
#   (12352, 3951)	0.05997768197341551
#   (12352, 15162)	0.08316179192349593
#   (12352, 31538)	0.06019473005762175
#   (12352, 20435)	0.035835596947955566
#   (12352, 28978)	0.03583850000925982
#   (12352, 27903)	0.03626499223938892
#   (12352, 18697)	0.27876514145344855
#   (12352, 37559)	0.06051397598145413
#   (12352, 2223)	0.059026062158921824
#   (12352, 2981)	0.06037172377916574
#   (12352, 10438)	0.060986412851631824
#   (12352, 27701)	0.06060318262513777
#   (12352, 13459)	0.057284605517979245
#   (12352, 34962)	0.09062275215120273
#   (12352, 15431)	0.2284939049907725
#   (12352, 35314)	0.15338476052639036
#   (12352, 31043)	0.20969016948451907
#   (12352, 41862)	0.20834224077318125
#   (12352, 42166)	0.13857277909382135
#   (12352, 193)	0.14276191212192949
#   (12352, 27069)	0.348891245816829
#   (12352, 453)	0.16139779323191825
#   (12352, 12200)	0.3730672147065845
#   (12352, 11029)	0.5843640856941781

# %% [markdown]
# #Cosine Similarity

# %%
similarity = cosine_similarity(feature_vectors)

# %%
print(similarity)
# Out:
# [[1.         0.12951651 0.10335865 ... 0.03838473 0.03691724 0.05298923]
#  [0.12951651 1.         0.12648551 ... 0.0429817  0.03436602 0.04305147]
#  [0.10335865 0.12648551 1.         ... 0.03488758 0.04034977 0.06866229]
#  ...
#  [0.03838473 0.0429817  0.03488758 ... 1.         0.1097578  0.10052896]
#  [0.03691724 0.03436602 0.04034977 ... 0.1097578  1.         0.18402694]
#  [0.05298923 0.04305147 0.06866229 ... 0.10052896 0.18402694 1.        ]]

# %%
print(similarity.shape)
# Out:
# (12353, 12353)

# %%
Web_Series_name = input(' Enter your favourite Web Series name : ')
# Out:
#  Enter your favourite Web Series name : Game of Thrones

# %%
list_of_all_titles = web_series_data['Series Title'].tolist()
print(list_of_all_titles)
# Out:
# ['Breaking Bad', 'Game of Thrones', 'Rick and Morty', 'Stranger Things', 'The Boys', 'Dark', 'Chernobyl', 'Sherlock', 'Fargo', 'Avatar: The Last Airbender', 'Friends', 'The Office', 'Supernatural', 'The Wire', 'Better Call Saul', 'Attack on Titan', 'Black Mirror', 'Band of Brothers', 'House', 'Lucifer', 'Money Heist', 'Mr. Robot', 'Peaky Blinders', 'Cobra Kai', 'The Simpsons', 'The Mandalorian', 'The Sopranos', 'The Umbrella Academy', 'Vikings', 'The Walking Dead', 'Lost', 'Brooklyn Nine-Nine', 'Sex Education', 'Mindhunter', 'Dexter', 'Narcos', 'Westworld', 'True Detective', 'South Park', 'Parks and Recreation', 'Mad Men', "Marvel's Daredevil", 'Firefly', 'Fringe', 'Shameless', 'The Big Bang Theory', 'Modern Family', 'Suits', 'The Last Dance', 'Community', "It's Always Sunny in Philadelphia", 'Twin Peaks', 'Hannibal', 'Ozark', 'Seinfeld', 'The Haunting', 'Fullmetal Alchemist: Brotherhood', 'The Witcher', 'The Fall', 'Homeland', 'The 100', 'How I Met Your Mother', 'The Good Place', 'The Expanse', "Grey's Anatomy", 'My Hero Academia', 'House of Cards', "The Handmaid's Tale", "Marvel's Agents of S.H.I.E.L.D.", 'Fleabag', 'The Crown', 'Outlander', 'When They See Us', 'Futurama', 'Sons of Anarchy', 'The Vampire Diaries', 'Prison Break', 'The Legend of Korra', 'Archer', 'Gravity Falls', 'Arrested Development', 'The Blacklist', 'Killing Eve', 'Last Week Tonight with John Oliver', 'Sacred Games', 'Orange Is the New Black', 'Yellowstone', 'Silicon Valley', 'Euphoria', 'The X-Files', 'The Flash', 'Justified', 'The Americans', 'This Is Us', 'Adventure Time', 'BoJack Horseman', 'The Marvelous Mrs. Maisel', 'The End of the F***ing World', 'Big Little Lies', 'Luther', 'Curb Your Enthusiasm', 'American Crime Story', 'Unbelievable', 'Boardwalk Empire', 'Orphan Black', 'The Last Kingdom', 'Rome', 'Batman: The Animated Series', 'Sense8', 'Six Feet Under', 'Penny Dreadful', 'Normal People', 'Scrubs', 'The IT Crowd', 'Once Upon a Time', 'Star Trek: The Next Generation', 'Broadchurch', 'Pride and Prejudice', 'Arrow', 'Chuck', 'Planet Earth II', '24', 'What We Do in the Shadows', 'The Night Of', 'Buffy the Vampire Slayer', 'White Collar', 'Billions', 'The West Wing', 'Love, Death & Robots', 'Legion', 'Ted Lasso', 'Psych', "Marvel's Jessica Jones", 'Kingdom', 'The Twilight Zone', 'How to Get Away with Murder', "Schitt's Creek", 'New Girl', 'The Shield', 'Line of Duty', 'Bodyguard', 'YOU', 'Friday Night Lights', 'Succession', 'Bosch', 'Deadwood', 'Pretty Little Liars', 'Raised by Wolves', 'Watchmen', 'Death Note', 'Atlanta', 'Bates Motel', "Marvel's The Punisher", 'The Leftovers', 'Doom Patrol', 'Mr. Bean', 'The Sinner', '30 Rock', 'The Man in the High Castle', "Chappelle's Show", 'Elementary', "Bob's Burgers", 'Naruto Shippūden', 'Dead to Me', 'Misfits', 'Altered Carbon', 'Good Girls', 'Teen Wolf', 'Good Omens', 'Master of None', 'Barry', "Tom Clancy's Jack Ryan", 'The Pacific', 'Making a Murderer', 'Unorthodox', 'The Office', 'The Good Wife', 'Taboo', 'Lovecraft Country', 'Upload', 'Elite', 'Doctor Who', 'Our Planet', 'Star Wars: The Clone Wars', 'American Horror Story', 'One Piece', 'Castle', '11.22.63', 'Kingdom', 'Gotham', 'Pushing Daisies', 'The Night Manager', 'Grimm', 'Hunter x Hunter', 'Bones', 'Ash vs Evil Dead', 'Frasier', 'The Morning Show', 'Russian Doll', 'One-Punch Man', 'Veronica Mars', 'Oz', 'Atypical', 'After Life', 'Criminal Minds', 'Steins;Gate', 'Black Books', 'Star Trek', 'Banshee', 'Narcos: Mexico', 'Sharp Objects', 'Battlestar Galactica', 'Black Sails', 'The OA', 'Veep', 'Gilmore Girls', 'The Outsider', 'The Killing', 'Big Mouth', 'The Newsroom', 'Burn Notice', 'Farscape', 'Person of Interest', 'The Alienist', 'Preacher', 'Never Have I Ever', 'True Blood', 'Spartacus', 'Tokyo Ghoul', 'Californication', 'Fawlty Towers', 'Counterpart', 'Ray Donovan', 'Peep Show', 'Halt and Catch Fire', 'Neon Genesis Evangelion', 'Naruto', 'Primal', 'Castlevania', 'Downton Abbey', 'Family Guy', 'The Grand Tour', 'Eureka', 'Revenge', 'Lie to Me',  ...

# %%
find_close_match = difflib.get_close_matches(Web_Series_name, list_of_all_titles)
print(find_close_match)
# Out:
# ['
245880244863936), (582, 0.2237760296582474), (4206, 0.2235008832428505), (707, 0.22343226982507067), (1999, 0.22268640164004108), (737, 0.22266078599352077), (4242, 0.222457419901514), (4328, 0.22140445721386784), (618, 0.2209328903990587), (4156, 0.22088380188117368), (214, 0.22056860983463025), (6143, 0.2190227794882151), (8992, 0.21897073898118272), (201, 0.21880126169146027), (819, 0.21858677124057027), (4352, 0.21839895825196506), (878, 0.2183041064527485), (898, 0.21811299617763694), (802, 0.21804377531827143), (4388, 0.21775589724796188), (1017, 0.21710324140324563), (579, 0.2170288298741489), (5260, 0.2169742965651189), (1898, 0.2159659367080842), (3329, 0.2156114847963961), (3338, 0.21481585092719102), (3546, 0.21458252051453008), (1290, 0.21452440442149592), (634, 0.2145055222563219), (422, 0.2132578867227637), (5738, 0.21314933530813193), (109, 0.21146764004617277), (964, 0.2113638090995679), (1207, 0.21092537929158361), (1858, 0.21046008493573193), (673, 0.20919129239828677), (5231, 0.20914161285707294), (26, 0.2082932938706191), (7314, 0.20798980066739736), (226, 0.2078779049455758), (6901, 0.20726812328279004), (341, 0.20722446093806138), (784, 0.20700090916595904), (1459, 0.2069983686328898), (5269, 0.20698084809964648), (153, 0.20646909573546174), (10, 0.2060965350870879), (2449, 0.20558387401473205), (2053, 0.20535966039281223), (11016, 0.2052138888285686), (219, 0.20455640257169763), (9686, 0.20417381641366095), (5407, 0.20415939201831138), (94, 0.20400927693173315), (11192, 0.20335672893730664), (5706, 0.20225179276614363), (713, 0.2017058752800189), (2549, 0.20158232594005263), (857, 0.2014812499369991), (1390, 0.20135324011097167), (977, 0.20129246243483553), (886, 0.2012553325090598), (3612, 0.20112394260969932), (237, 0.20066939491369765), (727, 0.2003464653533191), (6880, 0.20010031338729187), (4735, 0.20001567495273562), (1396, 0.19974718962235935), (3543, 0.19957762423151906), (6169, 0.19905440974786096), (6807, 0.19900041543718605), (100, 0.19849201377624082), (83, 0.1982433667 ...

# %%
print('Web Series Suggested For You : \n')

i = 1

for web_series in sorted_similar_web_series:
  index = web_series[0]
  title_from_index = web_series_data[web_series_data.index==index]['Series Title'].values[0]
  if (i<6):
    print(i, '.',title_from_index)
    i+=1
# Out:
# Web Series Suggested For You :
#
# 1 . Game of Thrones
# 2 . The World Between Us
# 3 . The Night Of
# 4 . The Weight of the Nation for Kids
# 5 . Looking

# %% [markdown]
# #Web Series Recommendation For Samy

# %%
Web_Series_name = input(' Enter your favourite Web Series name : ')

list_of_all_titles = web_series_data['Series Title'].tolist()

find_close_match = difflib.get_close_matches(Web_Series_name, list_of_all_titles)

close_match = find_close_match[0]

index_of_the_web_series = web_series_data[web_series_data['Series Title'] == close_match].index[0]

similarity_score = list(enumerate(similarity[index_of_the_web_series]))

sorted_similar_web_series = sorted(similarity_score, key = lambda x:x[1], reverse = True)

print('Web Series Suggested For You : \n')

i = 1

for web_series in sorted_similar_web_series:
  index = web_series[0]
  title_from_index = web_series_data[web_series_data.index==index]['Series Title'].values[0]
  if (i<11):
    print(i, '.',title_from_index)
    i+=1
# Out:
#  Enter your favourite Web Series name : Game of Thrones
# Web Series Suggested For You :
#
# 1 . Game of Thrones
# 2 . The World Between Us
# 3 . The Night Of
# 4 . The Weight of the Nation for Kids
# 5 . Looking
# 6 . Band of Brothers
# 7 . The Brink
# 8 . Rome
# 9 . A Little Curious
# 10 . The Wire
